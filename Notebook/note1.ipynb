# %%
from collections import namedtuple

# run pip install ipykernel if shows error

# %%
(12,234,34)
# Out:
# (12, 234, 34)

# %%
# named tuple  assign name to the every element in the tuple

DataIngestionConfig=namedtuple("DataIngestionConfig",
["dataset_download_url","tgz_download_dir",        "raw_data_dir",    "ingested_train_dir", "ingested_test_dir"])

# %%
DataIngestionConfig()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32516\1956480014.py in <module>
# ----> 1 DataIngestionConfig()
#
# TypeError: __new__() missing 5 required positional arguments: 'dataset_download_url', 'tgz_download_dir', 'raw_data_dir', 'ingested_train_dir', and 'ingested_test_dir'

# %%
import yaml

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end'

# %%
os.chdir('c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end'

# %%
os.listdir()
# Out:
# ['.dockerignore',
#  '.git',
#  '.github',
#  '.gitignore',
#  'app.py',
#  'config',
#  'demo.py',
#  'Dockerfile',
#  'housing',
#  'LICENSE',
#  'logs',
#  'ml.gif',
#  'Notebook',
#  'README.md',
#  'requirements.txt',
#  'setup.py',
#  'templates',
#  'venv']

# %%
os.listdir('config')
# Out:
# ['config.yaml', 'model.yaml', 'schema.yaml']

# %%
config_file_path = 'config/config.yaml'

# %%
config_file_path
# Out:
# 'config/config.yaml'

# %%
os.path.exists(config_file_path)
# Out:
# True

# %%
# read the file in yaml
import yaml
config_info = None

with open(config_file_path,'rb') as yaml_file:
    config_info = yaml.safe_load(yaml_file)

# %%
config_info
# Out:
# {'training_pipeline_config': {'pipeline_name': 'housing',
#   'artifact_dir': 'artifact'},
#  'data_ingestion_config': {'dataset_download_url': 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz',
#   'raw_data_dir': 'raw_data',
#   'tgz_download_dir': 'tgz_data',
#   'ingested_dir': 'ingested_data',
#   'ingested_train_dir': 'train',
#   'ingested_test_dir': 'test'},
#  'data_validation_config': {'schema_dir': 'config',
#   'schema_file_name': 'schema.yaml',
#   'report_file_name': 'report.json',
#   'report_page_file_name': 'report.html'},
#  'data_transformation_config': {'add_bedroom_per_room': True,
#   'transformed_dir': 'transformed_data',
#   'transformed_train_dir': 'train',
#   'transformed_test_dir': 'test',
#   'preprocessing_dir': 'preprocessed',
#   'preprocessed_object_file_name': 'preprocessed.pkl'},
#  'model_trainer_config': {'trained_model_dir': 'trained_model',
#   'model_file_name': 'model.pkl',
#   'base_accuracy': 0.6,
#   'model_config_dir': 'config',
#   'model_config_file_name': 'model.yaml'},
#  'model_evaluation_config': {'model_evaluation_file_name': 'model_evaluation.yaml'},
#  'model_pusher_config': {'model_export_dir': 'saved_models'}}

# %%
config_info['data_ingestion_config'] # to read ingestion configuration
# Out:
# {'dataset_download_url': 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz',
#  'raw_data_dir': 'raw_data',
#  'tgz_download_dir': 'tgz_data',
#  'ingested_dir': 'ingested_data',
#  'ingested_train_dir': 'train',
#  'ingested_test_dir': 'test'}

# %%
config_info['data_ingestion_config']['dataset_download_url']  # to read the url for dataset
# Out:
# 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz'

# %%
def read_yaml_file(file_path:str)->dict:
    """
    Reads a YAML file and returns the contents as a dictionary.
    file_path: str
    """
    try:
        with open(file_path, 'rb') as yaml_file:
            return yaml.safe_load(yaml_file)
    except Exception as e:
        raise HousingException(e,sys) from e

# %%
ROOT_DIR = os.getcwd()  #to get current working directory
CONFIG_DIR = "config"    # folder for config 
CONFIG_FILE_NAME = "config.yaml"   # name of the config file
CONFIG_FILE_PATH = os.path.join(ROOT_DIR,CONFIG_DIR,CONFIG_FILE_NAME)

# %%
CONFIG_FILE_PATH
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\config\\config.yaml'

# %%
k = read_yaml_file(CONFIG_FILE_PATH)
k
# Out:
# {'training_pipeline_config': {'pipeline_name': 'housing',
#   'artifact_dir': 'artifact'},
#  'data_ingestion_config': {'dataset_download_url': 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz',
#   'raw_data_dir': 'raw_data',
#   'tgz_download_dir': 'tgz_data',
#   'ingested_dir': 'ingested_data',
#   'ingested_train_dir': 'train',
#   'ingested_test_dir': 'test'},
#  'data_validation_config': {'schema_dir': 'config',
#   'schema_file_name': 'schema.yaml',
#   'report_file_name': 'report.json',
#   'report_page_file_name': 'report.html'},
#  'data_transformation_config': {'add_bedroom_per_room': True,
#   'transformed_dir': 'transformed_data',
#   'transformed_train_dir': 'train',
#   'transformed_test_dir': 'test',
#   'preprocessing_dir': 'preprocessed',
#   'preprocessed_object_file_name': 'preprocessed.pkl'},
#  'model_trainer_config': {'trained_model_dir': 'trained_model',
#   'model_file_name': 'model.pkl',
#   'base_accuracy': 0.6,
#   'model_config_dir': 'config',
#   'model_config_file_name': 'model.yaml'},
#  'model_evaluation_config': {'model_evaluation_file_name': 'model_evaluation.yaml'},
#  'model_pusher_config': {'model_export_dir': 'saved_models'}}

# %%
k['training_pipeline_config']
# Out:
# {'pipeline_name': 'housing', 'artifact_dir': 'artifact'}

# %%
k['data_ingestion_config']['raw_data_dir']
# Out:
# 'raw_data'

# %%
k['data_ingestion_config']['dataset_download_url']
# Out:
# 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz'

# %%
ROOT_DIR = os.getcwd()  #to get current working directory
CONFIG_DIR = "config"    # get the path of the config file
CONFIG_FILE_NAME = "config.yaml"   # get the path of the config.yaml file
CONFIG_FILE_PATH = os.path.join(ROOT_DIR,CONFIG_DIR,CONFIG_FILE_NAME)  # path of the config.yaml file

# %%
CONFIG_FILE_PATH
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\config\\config.yaml'

# %%
TRAINING_PIPELINE_CONFIG_KEY = "training_pipeline_config"
TRAINING_PIPELINE_ARTIFACT_DIR_KEY = "artifact_dir"
TRAINING_PIPELINE_NAME_KEY = "pipeline_name"

# %%
training_pipeline_config = config_info[TRAINING_PIPELINE_CONFIG_KEY]
training_pipeline_config
# Out:
# {'pipeline_name': 'housing', 'artifact_dir': 'artifact'}

# %%
artifact_dir = os.path.join(ROOT_DIR,
            training_pipeline_config[TRAINING_PIPELINE_NAME_KEY],
            training_pipeline_config[TRAINING_PIPELINE_ARTIFACT_DIR_KEY]
            )

# %%
artifact_dir
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact'

# %%
from housing.entity.config_entity import *

training_pipeline_config = TrainingPipelineConfig(artifact_dir=artifact_dir)

# %%
training_pipeline_config
# Out:
# TrainingPipelineConfig(artifact_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact')

# %%
from housing.config.configuration import *

# %%
config = Configuartion()

# %%
config.get_training_pipeline_config()
# Out:
# TrainingPipelineConfig(artifact_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact')

# %%
config.get_data_ingestion_config()
# Out:
# DataIngestionConfig(dataset_download_url='https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz', tgz_download_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\2023-01-19-20-12-54\\tgz_data', raw_data_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\2023-01-19-20-12-54\\raw_data', ingested_train_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\2023-01-19-20-12-54\\ingested_data\\train', ingested_test_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\2023-01-19-20-12-54\\ingested_data\\test')

# %%
artifact_dir = training_pipeline_config.artifact_dir  # this wil get the path of the aritifact dir
data_ingestion_artifact_dir=os.path.join(
                artifact_dir,
                DATA_INGESTION_ARTIFACT_DIR,
            ) # this line will get the complete path of the yaml file
data_ingestion_info = config_info[DATA_INGESTION_CONFIG_KEY]   # this will get the path of the yaml file
            
dataset_download_url = data_ingestion_info[DATA_INGESTION_DOWNLOAD_URL_KEY]  # this will get the url from the yaml file

tgz_download_dir = os.path.join(
                data_ingestion_artifact_dir,
                data_ingestion_info[DATA_INGESTION_TGZ_DOWNLOAD_DIR_KEY])

# %%
tgz_download_dir
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\tgz_data'

# %%
 raw_data_dir = os.path.join(data_ingestion_artifact_dir,
            data_ingestion_info[DATA_INGESTION_RAW_DATA_DIR_KEY]
            )

# %%
raw_data_dir
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\raw_data'

# %%
ingested_data_dir = os.path.join(
                data_ingestion_artifact_dir,
                data_ingestion_info[DATA_INGESTION_INGESTED_DIR_NAME_KEY]
            )

# %%
ingested_data_dir
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\ingested_data'

# %%
ingested_train_dir = os.path.join(
                ingested_data_dir,
                data_ingestion_info[DATA_INGESTION_TRAIN_DIR_KEY]
            )

# %%
ingested_train_dir
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\ingested_data\\train'

# %%
ingested_test_dir =os.path.join(
                ingested_data_dir,
                data_ingestion_info[DATA_INGESTION_TEST_DIR_KEY]
            )

# %%
ingested_test_dir
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\ingested_data\\test'

# %%
data_ingestion_config=DataIngestionConfig(
                dataset_download_url=dataset_download_url, 
                tgz_download_dir=tgz_download_dir, 
                raw_data_dir=raw_data_dir, 
                ingested_train_dir=ingested_train_dir, 
                ingested_test_dir=ingested_test_dir
            )

# %%
data_ingestion_config
# Out:
# DataIngestionConfig(dataset_download_url='https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz', tgz_download_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\tgz_data', raw_data_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\raw_data', ingested_train_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\ingested_data\\train', ingested_test_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\ingested_data\\test')

# %%
data_ingestion_config
# Out:
# DataIngestionConfig(dataset_download_url='https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz', tgz_download_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\tgz_data', raw_data_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\raw_data', ingested_train_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\ingested_data\\train', ingested_test_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\ingested_data\\test')

# %%
training_pipeline_config
# Out:
# TrainingPipelineConfig(artifact_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact')

# %%
data_ingestion_config.dataset_download_url
# Out:
# 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz'

# %%
data_ingestion_config.tgz_download_dir
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\tgz_data'

# %%
config.get_data_ingestion_config()
# Out:
# DataIngestionConfig(dataset_download_url='https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz', tgz_download_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\2023-01-19-20-12-54\\tgz_data', raw_data_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\2023-01-19-20-12-54\\raw_data', ingested_train_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\2023-01-19-20-12-54\\ingested_data\\train', ingested_test_dir='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\2023-01-19-20-12-54\\ingested_data\\test')

# %%
from housing.component.data_ingestion import *
DataIngestion(data_ingestion_config = config.get_data_ingestion_config())

# %%
data=DataIngestion(data_ingestion_config = config.get_data_ingestion_config())

# %%
data

# %%
artifact_dir
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact'

# %%
ROOT_DIR
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end'

# %%
training_pipeline_config[TRAINING_PIPELINE_NAME_KEY]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32516\2229902047.py in <module>
# ----> 1 training_pipeline_config[TRAINING_PIPELINE_NAME_KEY]
#
# TypeError: tuple indices must be integers or slices, not str

# %%
from housing.entity.config_entity import DataIngestionConfig, DataTransformationConfig,DataValidationConfig,   \
ModelTrainerConfig,ModelEvaluationConfig,ModelPusherConfig,TrainingPipelineConfig

def get_training_pipeline_config() ->TrainingPipelineConfig:
    training_pipeline_config = config_info[TRAINING_PIPELINE_CONFIG_KEY]
    artifact_dir = os.path.join(ROOT_DIR,
    training_pipeline_config[TRAINING_PIPELINE_NAME_KEY],
    training_pipeline_config[TRAINING_PIPELINE_ARTIFACT_DIR_KEY]
            )

    training_pipeline_config = TrainingPipelineConfig(artifact_dir=artifact_dir)
    return training_pipeline_config

# %%
config.get_data_validation_config()
# Out:
# DataValidationConfig(schema_file_path='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\config\\schema.yaml', report_file_path='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_validation\\2023-01-19-20-12-54\\report.json', report_page_file_path='c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_validation\\2023-01-19-20-12-54\\report.html')

# %%
artifact_dir = training_pipeline_config.artifact_dir

# %%
data_transformation_artifact_dir=os.path.join(
                artifact_dir,
                DATA_TRANSFORMATION_ARTIFACT_DIR,
                
            )

# %%
data_transformation_artifact_dir
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_transformation'

# %%
data_transformation_config_info=config_info[DATA_TRANSFORMATION_CONFIG_KEY]

# %%
data_transformation_config_info
# Out:
# {'add_bedroom_per_room': True,
#  'transformed_dir': 'transformed_data',
#  'transformed_train_dir': 'train',
#  'transformed_test_dir': 'test',
#  'preprocessing_dir': 'preprocessed',
#  'preprocessed_object_file_name': 'preprocessed.pkl'}

# %%
add_bedroom_per_room=data_transformation_config_info[DATA_TRANSFORMATION_ADD_BEDROOM_PER_ROOM_KEY]

# %%
add_bedroom_per_room
# Out:
# True

# %%
preprocessed_object_file_path = os.path.join(
                data_transformation_artifact_dir,
                data_transformation_config_info[DATA_TRANSFORMATION_PREPROCESSING_DIR_KEY],
                data_transformation_config_info[DATA_TRANSFORMATION_PREPROCESSED_FILE_NAME_KEY]
            )

# %%
preprocessed_object_file_path
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_transformation\\preprocessed\\preprocessed.pkl'

# %%
transformed_train_dir=os.path.join(
            data_transformation_artifact_dir,
            data_transformation_config_info[DATA_TRANSFORMATION_DIR_NAME_KEY],
            data_transformation_config_info[DATA_TRANSFORMATION_TRAIN_DIR_NAME_KEY]
            )

# %%
transformed_train_dir
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_transformation\\transformed_data\\train'

# %%
transformed_test_dir = os.path.join(
            data_transformation_artifact_dir,
            data_transformation_config_info[DATA_TRANSFORMATION_DIR_NAME_KEY],
            data_transformation_config_info[DATA_TRANSFORMATION_TEST_DIR_NAME_KEY]

            )

# %%
transformed_test_dir
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_transformation\\transformed_data\\test'

# %%
total_rooms_ix = columns.index(COLUMN_TOTAL_ROOMS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32516\2975082330.py in <module>
# ----> 1 total_rooms_ix = columns.index(COLUMN_TOTAL_ROOMS)
#
# NameError: name 'columns' is not defined

# %%
data_ingestion_config =config.get_data_ingestion_config()

# %%
data_ingestion_config.tgz_download_dir
# Out:
# 'c:\\Users\\91822\\Desktop\\git_hub\\Machine-Learning-project-end-to-end\\housing\\artifact\\data_ingestion\\2023-01-19-20-12-54\\tgz_data'
